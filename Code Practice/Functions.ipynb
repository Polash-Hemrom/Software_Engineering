# %% [markdown]
# #### Problem 1

# %%
## Write a simple functions

def greet():
    print('Hello, Python!')

# %% [markdown]
# #### Problem 2

# %%
## return square

def square(num1, num2):
    return (num1 * num2)

square (5,5)
# Out:
# 25

# %% [markdown]
# #### Problem 3

# %%
## Write a function that calculate even or odd number


def is_even(number):

    if number % 2 == 0:
        print ('True')
    else:
        print('False')


is_even(11)
# Out:
# False
