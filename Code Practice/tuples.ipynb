# %% [markdown]
# ### Level 0 Absolute Beginner

# %%
## Create a tuples...

tuple = ('Python', 'Java', 'C++')
print((tuple))
# Out:
# ('Python', 'Java', 'C++')

# %%
## Tuple Element Access

languages = ('Python', 'Java', 'C++', 'Go')

# Print first  element:
print(languages[0])

# Prnt last element:
print(languages[-1])

# Print C++
print(languages [2])

# Print Java
print(languages[1])
# Out:
# Python
# Go
# C++
# Java
