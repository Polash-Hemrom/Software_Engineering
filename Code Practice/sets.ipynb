# %% [markdown]
# ### Level 0 ___ Absolute Beginner

# %%
# 1. Create a set
language = {'Python', 'Java', 'C++', 'Go', 'Python'}
print(language)
# Out:
# {'Python', 'C++', 'Java', 'Go'}

# %%
# Set Uniqueness

numbers = {10, 20, 10, 30, 20, 40, 10}
print(numbers)
# Out:
# {40, 10, 20, 30}
