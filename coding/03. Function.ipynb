# %% [markdown]
# #### Level ---1 What is Function?

# %%
def say_hello():
    print('Hello, Polash')

say_hello()
# Out:
# Hello, Polash

# %% [markdown]
# #### Create Function

# %%
def greet():
    print('Hello')

# %% [markdown]
# #### Function Call

# %%
def greet():
    print('Hello')


greet()
# Out:
# Hello

# %% [markdown]
# #### 3. Why use function?

# %%
def add():

    number_1 = 20
    number_2 = 10
    print(number_1 + number_2)

# %% [markdown]
# #### Level _2 Parameters
